# %% [markdown]
# <a href="https://colab.research.google.com/github/jesuselizondo/Inteligencia-Artificial-y-Redes-Neuronales/blob/main/AF7_RNP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Actividad 7: Redes Neuronales Artificiales

# %%
# Zaira Villalobos García 2132006
# Nestor Alejandro Jimenez Barragan 2132189
# Emiliano Javier Elizondo Castillo 2058628
# Jesús Adrian Saucedo Elizondo 2062669
# Carlos Emilio Marrero Herrera 1928023
# IMPORTACION DE BIBLIOTECAS y CARGA DE DATOS
import keras
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Dense, Flatten\


(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# PROCESAMIENTO
train_images = x_train.reshape((60_000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = x_test.reshape((10_000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
# DISEÑO DEL MODELO

model = Sequential([
    Input(shape=(28 * 28,)),
    Dense(56, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(10, activation='softmax')
])

# COMPILACION DEL MODELO

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# ENTRENAMIENTO
history = model.fit(
    train_images, y_train,
    epochs=10,
    validation_data=(test_images, y_test)  # <-- Esto es clave
)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9923 - loss: 0.0232 - val_accuracy: 0.9698 - val_loss: 0.1292
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9920 - loss: 0.0240 - val_accuracy: 0.9765 - val_loss: 0.1012
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9925 - loss: 0.0230 - val_accuracy: 0.9722 - val_loss: 0.1192
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9939 - loss: 0.0200 - val_accuracy: 0.9736 - val_loss: 0.1222
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9929 - loss: 0.0203 - val_accuracy: 0.9742 - val_loss: 0.1286
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9948 - loss: 0.0160 - val_accuracy: 0.9755 - val_loss: 0.1270
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9939 - loss: 0.0187 - val_accuracy: 0.9738 - val_loss: 0.1412
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9952 - loss: 0.0140 - val_accuracy: 0.9752 - val_loss: 0.1319
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9945 - loss: 0.0171 - val_accuracy: 0.9741 - val_loss: 0.1279
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9959 - loss: 0.0134 - val_accuracy: 0.9727 - val_loss: 0.1398

# %%
# MOSTRAR DATOS DE ENTRENAMIENTO
test_data = model.evaluate(test_images, y_test)
print("Pérdida (loss) en test:", test_data[0])
print("Exactitud (accuracy) en test:", test_data[1])
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Pérdida de entrenamiento')
plt.plot(history.history['val_loss'], label='Pérdida de validación')
plt.title('Pérdida durante el entrenamiento')
plt.xlabel('Época')
plt.ylabel('Pérdida')
plt.legend()

# Graficar exactitud
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Exactitud de entrenamiento')
plt.plot(history.history['val_accuracy'], label='Exactitud de validación')
plt.title('Exactitud durante el entrenamiento')
plt.xlabel('Época')
plt.ylabel('Exactitud')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9691 - loss: 0.1661
# Pérdida (loss) en test: 0.13980962336063385
# Exactitud (accuracy) en test: 0.9726999998092651

# %%
# EJEMPLOS
plt.imshow(x_test[23].reshape(28, 28), cmap='gray')
pred = model.predict(test_images[23].reshape(1, 28 * 28))
plt.title(np.argmax(pred))
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step

# %%
plt.imshow(x_test[43].reshape(28, 28), cmap='gray')
pred = model.predict(test_images[43].reshape(1, 28 * 28))
plt.title(np.argmax(pred))
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
plt.imshow(x_test[234].reshape(28, 28), cmap='gray')
pred = model.predict(test_images[234].reshape(1, 28 * 28))
plt.title(np.argmax(pred))
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
plt.imshow(x_test[123].reshape(28, 28), cmap='gray')
pred = model.predict(test_images[123].reshape(1, 28 * 28))
plt.title(np.argmax(pred))
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
plt.imshow(x_test[456].reshape(28, 28), cmap='gray')
pred = model.predict(test_images[456].reshape(1, 28 * 28))
plt.title(np.argmax(pred))
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
